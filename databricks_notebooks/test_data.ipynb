# %%
spark.sql("SELECT *FROM driver_gold").show()
# Out:
# +---------+--------------+-----------+--------+
# |driver_id|total_earnings|total_trips|avg_fare|
# +---------+--------------+-----------+--------+
# |       93|         20.45|          1|   20.45|
# |       30|         98.47|          1|   98.47|
# |      200|        199.95|          1|  199.95|
# |      191|        181.19|          1|  181.19|
# |      170|        212.75|          2| 106.375|
# |       35|        183.26|          1|  183.26|
# |      131|        101.18|          1|  101.18|
# |      110|        192.35|          1|  192.35|
# |      195|        198.47|          1|  198.47|
# |      186|        319.74|          2|  159.87|
# |       38|         55.71|          1|   55.71|
# |       87|        136.43|          1|  136.43|
# |      126|        152.77|          1|  152.77|
# |      134|         167.6|          2|    83.8|
# |      123|        109.03|          1|  109.03|
# |      156|         89.43|          1|   89.43|
# |       48|         275.7|          2|  137.85|
# ...
